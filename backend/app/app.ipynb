# %%
from pathlib import Path
from fastapi import FastAPI, UploadFile, File, HTTPException
import os
import sys
import shutil
import tempfile
import base64
import io
import json
from pathlib import Path
from typing import Optional, Dict, List
app_dir = Path(__file__).parent  # backend/app/
backend_dir = app_dir.parent     # backend/
root_dir = backend_dir.parent    # root (LowLight-Object-Detection-Pipeline-WebApp/)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[4], line 12
#      10 from pathlib import Path
#      11 from typing import Optional, Dict, List
# ---> 12 app_dir = Path(__file__).parent  # backend/app/
#      13 backend_dir = app_dir.parent     # backend/
#      14 root_dir = backend_dir.parent    # root (LowLight-Object-Detection-Pipeline-WebApp/)
#
# NameError: name '__file__' is not defined

# %%
print(app_dir)
print(backend_dir)
print(root_dir)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 print(app_dir)
#       2 print(backend_dir)
#       3 print(root_dir)
#
# NameError: name 'app_dir' is not defined
